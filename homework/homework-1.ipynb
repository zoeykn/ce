# %% [markdown]
# ---
#
# ### 🎓 **Professor**: Apostolos Filippas
#
# ### 📘 **Class**: Introduction to AI Engineering
#
# ### 📋 **Homework 1**: Getting Started
#
# ### 📅 **Due Date**: Wednesday, January 21, 2025
#
# 🚫 **Note**: You are not allowed to share the contents of this notebook with anyone outside this class without written permission by the professor.
#
# ---

# %% [markdown]
# ## Instructions
#
# This homework tests whether you've successfully set up your development environment and understand the basics from Lecture 1.
#
# **How to complete this homework:**
# 1. Fill in the code cells where indicated
# 2. Run all cells to make sure they work
# 3. Save this notebook
# 4. Submit according to the instructions provided in class
#
# **Total Points: 100**

# %% [markdown]
# ---
#
# ## Task 1: GitHub Check-In (10 points)
#
# Create a Github account. Then go to the class repository and comment on Issue #1 with your GitHub username and Fordham email.
#
# **Link**: https://github.com/apostolosfilippas/ce/issues/1
#
# **Your comment should look like:**
# ```
# GitHub: your-username
# Email: yourname@fordham.edu
# ```
#
# Once you've commented, write your GitHub username below:

# %%
# Task 1: Write your GitHub username as a string
my_github_username = ""  # Fill in your username between the quotes

print(f"My GitHub username is: {my_github_username}")

# %% [markdown]
# ---
#
# ## Task 2: Terminal Navigation (20 points)
#
# Use terminal commands to navigate your file system. Remember, `!` at the start of a line runs it as a terminal command.
#
# ### 2a. Where are you? (5 pts)
# Use `pwd` to print your current working directory.

# %%
# Task 2a: Print your current working directory

# %% [markdown]
# ### 2b. What's here? (5 pts)
# Use `ls` to list the files and folders in the current directory.

# %%
# Task 2b: List files in the current directory

# %% [markdown]
# ### 2c. Navigate and explore (10 pts)
# In a single cell:
# 1. Go up one directory (`cd ..`)
# 2. List what's there (`ls`)
# 3. Go into the `scripts` folder (`cd scripts`). What would you do if it doesn't exist?
# 4. List the contents (`ls`)
#
# **Hint**: You can chain commands with `&&` like: `!cd .. && ls`

# %%
# Task 2c: Navigate around (use && to chain commands)

# %% [markdown]
# ---
#
# ## Task 3: Python and uv (20 points)
#
# Verify that Python and uv are properly installed.
#
# ### 3a. Check uv version (5 pts)

# %%
# Task 3a: Show your uv version

# %% [markdown]
# ### 3b. Check Python version (5 pts)

# %%
# Task 3b: Show your Python version (using uv run)

# %% [markdown]
# ### 3c. Run Python code (10 pts)
# Use `uv run python -c` to print: `Hello, AI Engineering!`

# %%
# Task 3c: Print "Hello, AI Engineering!" using uv run python -c

# %% [markdown]
# ---
#
# ## Task 4: Jupyter Skills (30 points)
#
# Demonstrate that you understand how Jupyter notebooks work.
#
# ### 4a. Create variables (10 pts)
# Create two variables:
# - `my_name` - your first name as a string
# - `my_favorite_number` - your favorite number as an integer

# %%
# Task 4a: Create the variables
my_name = ""  # Your first name
my_favorite_number = 0  # Your favorite number

# %% [markdown]
# ### 4b. Use variables across cells (10 pts)
# In the cell below, use the variables you created above to print:
# `"Hi, my name is [name] and my favorite number is [number]"`
#
# **Important**: You must run the cell above first!

# %%
# Task 4b: Print a message using the variables from the previous cell

# %% [markdown]
# ### 4c. Work with numpy (10 pts)
# 1. Import numpy as np
# 2. Create an array with the numbers 1 through 10
# 3. Print the array, its sum, and its mean

# %%
# Task 4c: Import numpy, create array, compute sum and mean

# %% [markdown]
# ---
#
# ## Task 5: Git Basics (20 points)
#
# ### 5a. Check git status (10 pts)
# Run `git status` to see the current state of the repository.

# %%
# Task 5a: Show git status

# %% [markdown]
# ### 5b. Explain git pull (10 pts)
# In your own words (1-2 sentences), explain what the `git pull` command does. Write your answer in the cell below as a comment or print statement.

# %%
# Task 5b: Explain what git pull does
# Your answer:

# %% [markdown]
# ---
#
# ## 🎉 Submission Checklist
#
# Before submitting, make sure:
#
# - [ ] You commented on GitHub Issue #1
# - [ ] All code cells run without errors
# - [ ] You saved this notebook (Ctrl+S / Cmd+S)
# - [ ] You followed the submission instructions from class
#
# **Great job completing your first homework!**
